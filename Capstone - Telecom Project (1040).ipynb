# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# %matplotlib inline

# %%
# read gender_age_train

gender_age = pd.read_csv("data\gender_age_train.csv")

gender_age.head()
# Out:
#    slno            device_id gender  age   group
# 0     0 -8076087639492063270      M   35  M32-38
# 1     1 -2897161552818060146      M   35  M32-38
# 2     2 -8260683887967679142      M   35  M32-38
# 3     3 -4938849341048082022      M   30  M29-31
# 4     4   245133531816851882      M   30  M29-31

# %%
gender_age.drop('slno', axis=1, inplace=True)

gender_age.head()
# Out:
#              device_id gender  age   group
# 0 -8076087639492063270      M   35  M32-38
# 1 -2897161552818060146      M   35  M32-38
# 2 -8260683887967679142      M   35  M32-38
# 3 -4938849341048082022      M   30  M29-31
# 4   245133531816851882      M   30  M29-31

# %%
# Count of Male and Female
gender_age.gender.value_counts().plot(kind='bar')

# %%
gender_age.columns
# Out:
# Index(['device_id', 'gender', 'age', 'group'], dtype='object')

# %%
gender_age.group.unique()
# Out:
# array(['M32-38', 'M29-31', 'F24-26', 'F33-42', 'F27-28', 'M39+', 'M23-26',
#        'M27-28', 'M22-', 'F43+', 'F23-', 'F29-32'], dtype=object)

# %%
gender_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74645 entries, 0 to 74644
# Data columns (total 4 columns):
# device_id    74645 non-null int64
# gender       74645 non-null object
# age          74645 non-null int64
# group        74645 non-null object
# dtypes: int64(2), object(2)
# memory usage: 2.3+ MB

# %%
# replacing all negative device id.

gender_age.device_id = abs(gender_age.device_id)
gender_age
# Out:
#                  device_id gender  age   group
# 0      8076087639492063270      M   35  M32-38
# 1      2897161552818060146      M   35  M32-38
# 2      8260683887967679142      M   35  M32-38
# 3      4938849341048082022      M   30  M29-31
# 4       245133531816851882      M   30  M29-31
# 5      1297074871525174196      F   24  F24-26
# 6       236877999787307864      M   36  M32-38
# 7      8098239495777311881      M   38  M32-38
# 8       176515041953473526      M   33  M32-38
# 9      1596610250680140042      F   36  F33-42
# 10     9032155484127182494      M   31  M29-31
# 11     7477216237379271436      F   37  F33-42
# 12     2478205222798310601      F   28  F27-28
# 13     6352067998666467520      M   32  M32-38
# 14     7605360767281960867      M   48    M39+
# 15     1508636020748379883      F   28  F27-28
# 16     4380872794486415327      M   38  M32-38
# 17     1039701474753771322      M   38  M32-38
# 18     6876541075223249434      M   75    M39+
# 19     6287938418661076759      M   33  M32-38
# 20     6029676723224952628      F   39  F33-42
# 21     8026504930081700361      M   25  M23-26
# 22     1118970699362079126      M   24  M23-26
# 23     7271319853104672050      M   27  M27-28
# 24     9216966316587614491      M   29  M29-31
# 25     4913644674161904021      M   34  M32-38
# 26     2313145512701915151      M   34  M32-38
# 27     4309468945717577632      F   36  F33-42
# 28     4547337748907986143      M   37  M32-38
# 29     7216269352973401877      M   37  M32-38
# ...                    ...    ...  ...     ...
# 74615  7826033719277536366      M   28  M27-28
# 74616  8939634378631061484      M   31  M29-31
# 74617  1676125742207316285      F   28  F27-28
# 74618  2627933310180294504      M   31  M29-31
# 74619  7176422141809079294      M   23  M23-26
# 74620   877731366874189491      M   22    M22-
# 74621  1324027033843938692      M   22    M22-
# 74622  3569962198902678507      F   59    F43+
# 74623  2032262288045492186      F   29  F29-32
# 74624  6220019934264142137      M   29  M29-31
# 74625  4071460957162948519      F   27  F27-28
# 74626  8012242415081116163      F   30  F29-32
# 74627  7513478293429751074      F   56    F43+
# 74628  2918022610076499795      M   26  M23-26
# 74629   442105793738318663      M   35  M32-38
# 74630  2510601842775405069      F   22    F23-
# 74631  2572857383593438598      F   21    F23-
# 74632  5804749754315732086      M   33  M32-38
# 74633  4229815843211107303      M   53    M39+
# 74634  8331157719771660970      M   53    M39+
# 74635  1728576663562073800      M   38  M32-38
# 74636  8116314513428390753      M   25  M23-26
# 74637  3539330294838027409      M   25  M23-26
# 74638  5645813107043557722      F   51    F43+
# 74639  4752726726975186730      M   26  M23-26
# 74640  4682031842235089751      M   30  M29-31
# 74641  9178703742877135986      M   30  M29-31
# 74642   180946546684162312      M   20    M22-
# 74643  1390702386071991851      M   37  M32-38
# 74644    89181010588227347      M   25  M23-26
#
# [74645 rows x 4 columns]

# %%
#checking null values

gender_age.isna().count()
# Out:
# device_id    74645
# gender       74645
# age          74645
# group        74645
# dtype: int64

# %%
# Count the unique device_id

gender_age.device_id.nunique()
# Out:
# 74645

# %%
# count the unique age group

gender_age.group.nunique()
# Out:
# 12

# %%
gender_age.shape
# Out:
# (74645, 4)

# %%
# read phone_brand table

phone_brand = pd.read_csv("data\phone_brand_device_model.csv")

phone_brand.head()
# Out:
#    Unnamed: 0            device_id phone_brand device_model
# 0           0  1877775838486905855        vivo          Y13
# 1           1 -3766087376657242966          小米         V183
# 2           2 -6238937574958215831        OPPO          R7s
# 3           3  8973197758510677470          三星        A368t
# 4           4 -2015528097870762664          小米      红米Note2

# %%
phone_brand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87726 entries, 0 to 87725
# Data columns (total 4 columns):
# Unnamed: 0      87726 non-null int64
# device_id       87726 non-null int64
# phone_brand     87726 non-null object
# device_model    87726 non-null object
# dtypes: int64(2), object(2)
# memory usage: 2.7+ MB

# %%
#checking null values

phone_brand.isna().count()
# Out:
# Unnamed: 0      87726
# device_id       87726
# phone_brand     87726
# device_model    87726
# dtype: int64

# %%
phone_brand.shape
# Out:
# (87726, 4)

# %%
gender_Phone_brand = pd.merge(gender_age,phone_brand,on = 'device_id',how='inner')

gender_Phone_brand.head(10)
# Out:
#              device_id gender  age   group  Unnamed: 0 phone_brand  \
# 0   245133531816851882      M   30  M29-31       13110       SUGAR
# 1   236877999787307864      M   36  M32-38       68989          酷派
# 2   176515041953473526      M   33  M32-38       13112          华为
# 3  1596610250680140042      F   36  F33-42       67545          三星
# 4  9032155484127182494      M   31  M29-31       77024          华为
# 5  7477216237379271436      F   37  F33-42       56028          华为
# 6  2478205222798310601      F   28  F27-28       67152          三星
# 7  6352067998666467520      M   32  M32-38       13113          三星
# 8  1508636020748379883      F   28  F27-28       13114          三星
# 9  4380872794486415327      M   38  M32-38       13115          三星
#
#     device_model
# 0           时尚手机
# 1             F2
# 2          G610S
# 3      Galaxy S4
# 4         Mate 7
# 5       荣耀6 plus
# 6  Galaxy Note 3
# 7      Galaxy S3
# 8      Galaxy S3
# 9      Galaxy S3

# %%
gender_Phone_brand.shape
# Out:
# (37223, 7)

# %%
# create dictionary to map phone_brand symbols to English mapping

phone_brand_map = {'华为':'Huawei','小米':'Xiaomi','三星':'Samsung','vivo':'vivo','OPPO':'OPPO','魅族':'Meizu','酷派':'Coolpad','乐视':'LeEco','联想':'Lenovo','HTC':'HTC'}

phone_brand_map
# Out:
# {'华为': 'Huawei',
#  '小米': 'Xiaomi',
#  '三星': 'Samsung',
#  'vivo': 'vivo',
#  'OPPO': 'OPPO',
#  '魅族': 'Meizu',
#  '酷派': 'Coolpad',
#  '乐视': 'LeEco',
#  '联想': 'Lenovo',
#  'HTC': 'HTC'}

# %%
# map phone_brand chinese name to English name

def getBrandValue(symbol):
    '''
    Function to get the Brand value based on symbol
    '''
    if symbol not in phone_brand_map:
        return symbol
    else:
        return phone_brand_map[symbol]

# %%
# apply the function to column

gender_Phone_brand['EnglishBrandName'] = gender_Phone_brand.apply(lambda x:getBrandValue(x['phone_brand']),axis=1)

gender_Phone_brand
# Out:
#                  device_id gender  age   group  Unnamed: 0 phone_brand  \
# 0       245133531816851882      M   30  M29-31       13110       SUGAR
# 1       236877999787307864      M   36  M32-38       68989          酷派
# 2       176515041953473526      M   33  M32-38       13112          华为
# 3      1596610250680140042      F   36  F33-42       67545          三星
# 4      9032155484127182494      M   31  M29-31       77024          华为
# 5      7477216237379271436      F   37  F33-42       56028          华为
# 6      2478205222798310601      F   28  F27-28       67152          三星
# 7      6352067998666467520      M   32  M32-38       13113          三星
# 8      1508636020748379883      F   28  F27-28       13114          三星
# 9      4380872794486415327      M   38  M32-38       13115          三星
# 10     6287938418661076759      M   33  M32-38       85956          小米
# 11     8026504930081700361      M   25  M23-26       13117          小米
# 12     1118970699362079126      M   24  M23-26       13118          魅族
# 13     2313145512701915151      M   34  M32-38       13121        vivo
# 14     4309468945717577632      F   36  F33-42       73793          三星
# 15     7630241409816671260      M   35  M32-38       53566        vivo
# 16     7106922851105968241      M   22    M22-       13123          天语
# 17     5886404762741543631      M   37  M32-38       68794          小米
# 18     3444770318780911055      M   36  M32-38       13125          三星
# 19     3549658489155683094      M   26  M23-26       77532        OPPO
# 20     3014072209520807550      M   28  M27-28       68422          魅族
# 21     6870382681059864892      M   29  M29-31       13133          小米
# 22     6677393742805480020      M   31  M29-31       74906          酷派
# 23     1865480732945072123      M   31  M29-31       81651          酷派
# 24      336916678843446187      F   36  F33-42       13134          三星
# 25      670584488453511085      F   36  F33-42       13135          小米
# 26     5874501925603975585      M   38  M32-38       59697          华为
# 27     3098621662950438701      M   31  M29-31       58865        vivo
# 28     6223951438363242934      M   28  M27-28       13142          小米
# 29     5938577683122528158      M   48    M39+       13147          三星
# ...                    ...    ...  ...     ...         ...         ...
# 37193  9142061250736882284      F   28  F27-28       52732          小米
# 37194  8760360510061416783      M   38  M32-38       52733         HTC
# 37195   397016735179188936      M   52    M39+       57964          小米
# 37196  5620443603680005134      F   31  F29-32       52736          小米
# 37197  7713308859694505501      M   26  M23-26       52737          三星
# 37198  5031327653177289618      M   32  M32-38       52739          华为
# 37199  7041398722782024994      M   22    M22-       52864          小米
# 37200  1069690787522952559      M   30  M29-31       70315          朵唯
# 37201  2176233713743660686      F   22    F23-       81253          三星
# 37202  1544087454490588295      M   27  M27-28       57645          华为
# 37203   804805193693465712      M   30  M29-31       81909          小米
# 37204  2835673032311494522      M   28  M27-28       52747          小米
# 37205  3177897734565028992      M   30  M29-31       52748          三星
# 37206  7913401700555773883      F   53    F43+       80971          三星
# 37207  7826033719277536366      M   28  M27-28       52749          三星
# 37208  8939634378631061484      M   31  M29-31       79647         TCL
# 37209  1676125742207316285      F   28  F27-28       52750          华为
# 37210  2627933310180294504      M   31  M29-31       52751          三星
# 37211  7176422141809079294      M   23  M23-26       52752          小米
# 37212  2032262288045492186      F   29  F29-32       52754          小米
# 37213  8012242415081116163      F   30  F29-32       52756          三星
# 37214  2918022610076499795      M   26  M23-26       64293          小米
# 37215   442105793738318663      M   35  M32-38       52758          小米
# 37216  1728576663562073800      M   38  M32-38       52763          魅族
# 37217  8116314513428390753      M   25  M23-26       52764          三星
# 37218  5645813107043557722      F   51    F43+       69770          小米
# 37219  4682031842235089751      M   30  M29-31       52767         联想
# 37220   180946546684162312      M   20    M22-       67356          小米
# 37221  1390702386071991851      M   37  M32-38       79422          华为
# 37222    89181010588227347      M   25  M23-26       52769          华为
#
#              device_model EnglishBrandName
# 0                    时尚手机            SUGAR
# 1                      F2          Coolpad
# 2                   G610S           Huawei
# 3               Galaxy S4          Samsung
# 4                  Mate 7           Huawei
# 5                荣耀6 plus           Huawei
# 6           Galaxy Note 3          Samsung
# 7               Galaxy S3          Samsung
# 8               Galaxy S3          Samsung
# 9               Galaxy S3          Samsung
# 10                   MI 3           Xiaomi
# 11                   MI 3           Xiaomi
# 12                    MX2            Meizu
# 13                  Xplay             vivo
# 14          Galaxy Note 3          Samsung
# 15                  Xplay             vivo
# 16                Touch 3               天语
# 17                   MI 3           Xiaomi
# 18          Galaxy Note 2          Samsung
# 19                  R827T             OPPO
# 20                    MX4            Meizu
# 21                  MI 2A           Xiaomi
# 22                   大神F2          Coolpad
# 23                     F2          Coolpad
# 24              Galaxy S4          Samsung
# 25                  MI 2A           Xiaomi
# 26                   G510           Huawei
# 27                  X5Max             vivo
# 28                  MI 2S           Xiaomi
# 29          Galaxy Note 3          Samsung
# ...                   ...              ...
# 37193                MI 4           Xiaomi
# 37194          Desire 820              HTC
# 37195                MI 3           Xiaomi
# 37196             红米Note2           Xiaomi
# 37197           Galaxy J5          Samsung
# 37198           Ascend P7           Huawei
# 37199               MI 2S           Xiaomi
# 37200             L5 mini               朵唯
# 37201          Galaxy Win          Samsung
# 37202                荣耀3X           Huawei
# 37203           红米note增强版           Xiaomi
# 37204               MI 2S           Xiaomi
# 37205  Galaxy Note 3 Lite          Samsung
# 37206       Galaxy Note 2          Samsung
# 37207      Galaxy Trend 2          Samsung
# 37208               P301M              TCL
# 37209        Ascend G330C           Huawei
# 37210  Galaxy Grand Prime          Samsung
# 37211             note顶配版           Xiaomi
# 37212           ELIFE E3T           Xiaomi
# 37213               A788t          Samsung
# 37214                MI 2           Xiaomi
# 37215             红米Note2           Xiaomi
# 37216                 MX3            Meizu
# 37217           Galaxy S3          Samsung
# 37218                MI 4           Xiaomi
# 37219               Q802T              联想
# 37220              红米note           Xiaomi
# 37221           Ascend P8           Huawei
# 37222           Ascend P8           Huawei
#
# [37223 rows x 8 columns]

# %%
#checking null values

gender_Phone_brand.isna().count()
# Out:
# device_id           37223
# gender              37223
# age                 37223
# group               37223
# Unnamed: 0          37223
# phone_brand         37223
# device_model        37223
# EnglishBrandName    37223
# dtype: int64

# %%
# Get unique phone brand

gender_Phone_brand.phone_brand.unique()
# Out:
# array(['SUGAR', '酷派', '华为', '三星', '小米', '魅族', 'vivo', '天语', 'OPPO', 'HTC',
#        '努比亚', 'LG', 'TCL', '联想 ', '优米', '一加', '酷比魔方', '海信', '欧博信', '朵唯',
#        '奇酷', '艾优尼', '锤子', '尼比鲁', '糯米', '优购', '乐视', '青橙', '酷比', '华硕',
#        '摩托罗拉', '夏新', '维图', 'LOGO', '富可视', '乡米', '米奇', '语信', '亿通', '波导',
#        '西米', '美图', '梦米', '飞秒', '先锋', '米歌', '德赛', '爱派尔', '中国移动', '至尊宝',
#        '纽曼', '长虹', '普耐尔', '海尔', '百立丰', '酷珀', 'ZUK', '昂达', '小杨树', '基伍',
#        '邦华', '贝尔丰', '诺亚信', 'E派', '欧奇', '诺基亚', 'MIL', '斐讯', '唯米', 'Lovme',
#        '康佳', '白米', '黑米', '易派', '果米', '大可乐', '宝捷讯', '聆韵', '百加', '瑞米', '瑞高',
#        '沃普丰', '台电', '大Q', '广信', '青葱', '摩乐', '欧新', '奥克斯', '谷歌', '蓝魔',
#        '恒宇丰', '神舟', '丰米', '鲜米', '智镁', '欧比', '唯比', '飞利浦', '欧乐迪'],
#       dtype=object)

# %%
# read events data

events = pd.read_csv("data\events_data.csv")

events.head(10)
# Out:
#    event_id     device_id            timestamp  longitude  latitude   city  \
# 0       1.0  2.918269e+16  2016-05-01 00:55:25  77.266049  28.68161  Delhi
# 1    7104.0  2.918269e+16  2016-05-02 09:37:02  77.266049  28.68161  Delhi
# 2   29661.0  2.918269e+16  2016-05-04 00:56:04  77.266049  28.68161  Delhi
# 3   33133.0  2.918269e+16  2016-05-06 05:01:15  77.266049  28.68161  Delhi
# 4   38980.0  2.918269e+16  2016-05-06 09:55:04  77.266049  28.68161  Delhi
# 5   66398.0  2.918269e+16  2016-05-01 01:56:06  77.266049  28.68161  Delhi
# 6   70894.0  2.918269e+16  2016-05-06 01:14:46  77.266049  28.68161  Delhi
# 7   87185.0  2.918269e+16  2016-05-01 09:20:01  77.266049  28.68161  Delhi
# 8   94644.0  2.918269e+16  2016-05-07 07:16:35  77.266049  28.68161  Delhi
# 9  110018.0  2.918269e+16  2016-05-06 21:00:40  77.266049  28.68161  Delhi
#
#    state
# 0  Delhi
# 1  Delhi
# 2  Delhi
# 3  Delhi
# 4  Delhi
# 5  Delhi
# 6  Delhi
# 7  Delhi
# 24537         Delhi    Delhi
# 24656         Delhi    Delhi
# 24846         Delhi    Delhi
# 24938         Delhi    Delhi
# 25007         Delhi    Delhi
# 25217         Delhi    Delhi
# 25304         Delhi    Delhi
# 25476         Delhi    Delhi
# ...             ...      ...
# 3080081  Hoshiarpur   Punjab
# 3080113  Hoshiarpur   Punjab
# 3080151  Hoshiarpur   Punjab
# 3080163  Hoshiarpur   Punjab
# 3080172  Hoshiarpur   Punjab
# 3080198  Hoshiarpur   Punjab
# 3080209  Hoshiarpur   Punjab
# 3080231  Hoshiarpur   Punjab
# 3080242  Hoshiarpur   Punjab
# 3080286  Hoshiarpur   Punjab
# 3080318  Hoshiarpur   Punjab
# 3080386  Hoshiarpur   Punjab
# 3080414  Hoshiarpur   Punjab
# 3080439  Hoshiarpur   Punjab
# 3098537     Bardoli  Gujarat
# 3098538     Bardoli  Gujarat
# 3098572     Bardoli  Gujarat
# 3098596     Bardoli  Gujarat
# 3098628     Bardoli  Gujarat
# 3098643     Bardoli  Gujarat
# 3098666     Bardoli  Gujarat
# 3098678     Bardoli  Gujarat
# 3098687     Bardoli  Gujarat
# 3098713     Bardoli  Gujarat
# 3098724     Bardoli  Gujarat
# 3098746     Bardoli  Gujarat
# 3098757     Bardoli  Gujarat
# 3098801     Bardoli  Gujarat
# 3098833     Bardoli  Gujarat
# 3098901     Bardoli  Gujarat
#
# [1253 rows x 7 columns]

# %%
# dispaly the data of selected states

select = ['MadhyaPradesh', 'Chhattisgarh', 'Uttaranchal', 'JammuandKashmir','Goa', 'Nag']

selectedStates = pd.DataFrame()
for index,value in enumerate(select):
    selectedStates=selectedStates.append(events[events.state == select[index]])
print(selectedStates)
# Out:
#           event_id     device_id            timestamp  longitude   latitude  \
# 2197849    10117.0 -5.323073e+18  2016-05-01 11:11:24  75.939543  22.769170
# 2197850   112369.0 -5.323073e+18  2016-05-04 22:47:19  75.939543  22.769170
# 2197851   139098.0 -5.323073e+18  2016-05-01 09:55:58  75.939543  22.769170
# 2197852   190983.0 -5.323073e+18  2016-05-04 22:51:03  75.939543  22.769170
# 2197853   249507.0 -5.323073e+18  2016-05-01 11:24:12  75.939543  22.769170
# 2197854   331448.0 -5.323073e+18  2016-05-01 09:54:27  75.939543  22.769170
# 2197855   508930.0 -5.323073e+18  2016-05-01 11:11:55  75.939543  22.769170
# 2197856   814402.0 -5.323073e+18  2016-05-01 11:14:55  75.939543  22.769170
# 2197857   814404.0 -5.323073e+18  2016-05-01 11:17:46  75.939543  22.769170
# 2197858   842681.0 -5.323073e+18  2016-05-01 11:27:42  75.939543  22.769170
# 2197859   899601.0 -5.323073e+18  2016-05-01 11:13:25  75.939543  22.769170
# 2197860   899602.0 -5.323073e+18  2016-05-01 11:13:55  75.939543  22.769170
# 2197861   925287.0 -5.323073e+18  2016-05-01 11:18:09  75.939543  22.769170
# 2197862   985123.0 -5.323073e+18  2016-05-01 11:33:48  75.939543  22.769170
# 2197863  1062002.0 -5.323073e+18  2016-05-01 11:05:40  75.939543  22.769170
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258799 entries, 2197849 to 2458895
# Data columns (total 7 columns):
# event_id     258799 non-null float64
# device_id    258748 non-null float64
# timestamp    258799 non-null object
# longitude    258736 non-null float64
# latitude     258736 non-null float64
# city         258799 non-null object
# state        258799 non-null object
# dtypes: float64(4), object(3)
# memory usage: 15.8+ MB

# %%
#Checking null values in selected states
selectedStates.isnull().sum()
# Out:
# event_id      0
# device_id    51
# timestamp     0
# longitude    63
# latitude     63
# city          0
# state         0
# dtype: int64

# %% [markdown]
# There are 51 rows null in selectedStates dataset

# %%
# Converting negative device_id to positive
selectedStates['device_id'] = np.abs(selectedStates['device_id'])

# %%
# Dropping rows with null device_id

selectedStates.dropna(subset=['device_id'],inplace = True)
selectedStates.isnull().sum()
# Out:
# event_id      0
# device_id     0
# timestamp     0
# longitude    63
# latitude     63
# city          0
# state         0
# dtype: int64

# %%
# Display rows with missing long and latitude

selectedStates[selectedStates.isnull().any(axis=1)]

# All missing values are belong to city "Indore" and state MadhyaPradesh
# Out:
#           event_id     device_id            timestamp  longitude  latitude  \
# 2209280    98473.0  2.350979e+18  2016-05-01 13:26:19        NaN       NaN
# 2209338   306267.0  2.350979e+18  2016-05-04 12:28:22        NaN       NaN
# 2209342   325499.0  2.350979e+18  2016-05-03 00:04:38        NaN       NaN
# 2209409   548071.0  2.350979e+18  2016-05-03 10:15:01        NaN       NaN
# 2209447   670642.0  2.350979e+18  2016-05-01 09:39:47        NaN       NaN
# 2209493   844848.0  2.350979e+18  2016-05-02 12:02:29        NaN       NaN
# 2209510   896615.0  2.350979e+18  2016-05-01 09:22:15        NaN       NaN
# 2209512   904180.0  2.350979e+18  2016-05-03 15:28:15        NaN       NaN
# 2209655  1565626.0  2.350979e+18  2016-05-03 22:31:58        NaN       NaN
# 2209667  1634714.0  2.350979e+18  2016-05-02 03:57:30        NaN       NaN
# 2209732  1945373.0  2.350979e+18  2016-05-04 20:26:49        NaN       NaN
# 2209776  2095096.0  2.350979e+18  2016-05-02 23:05:30        NaN       NaN
# 2209789  2180897.0  2.350979e+18  2016-05-04 10:38:52        NaN       NaN
# 2209804  2234686.0  2.350979e+18  2016-05-03 11:31:51        NaN       NaN
# 2209827  2338055.0  2.350979e+18  2016-05-01 13:08:52        NaN       NaN
# 2209828  2338514.0  2.350979e+18  2016-05-01 15:50:54        NaN       NaN
# 2209844  2402811.0  2.350979e+18  2016-05-02 15:59:54        NaN       NaN
# 2209886  2611498.0  2.350979e+18  2016-05-04 10:43:36        NaN       NaN
# 2209950  2895516.0  2.350979e+18  2016-05-01 01:05:25        NaN       NaN
# 2210006  3116310.0  2.350979e+18  2016-05-04 17:55:47        NaN       NaN
# 2210038  3245107.0  2.350979e+18  2016-05-04 19:27:21        NaN       NaN
# 2210859   153906.0  8.790560e+18  2016-05-05 15:44:35        NaN       NaN
# 2210917   358653.0  8.790560e+18  2016-05-05 13:18:02        NaN       NaN
# 2209280  Indore  MadhyaPradesh
# 2209338  Indore  MadhyaPradesh
# 2209342  Indore  MadhyaPradesh
# 2209409  Indore  MadhyaPradesh
# 2209447  Indore  MadhyaPradesh
# 2209493  Indore  MadhyaPradesh
# 2209510  Indore  MadhyaPradesh
# 2209512  Indore  MadhyaPradesh
# 2209655  Indore  MadhyaPradesh
# 2209667  Indore  MadhyaPradesh
# 2209732  Indore  MadhyaPradesh
# 2209776  Indore  MadhyaPradesh
# 2209789  Indore  MadhyaPradesh
# 2209804  Indore  MadhyaPradesh
# 2209827  Indore  MadhyaPradesh
# 2209828  Indore  MadhyaPradesh
# 2209844  Indore  MadhyaPradesh
# 2209886  Indore  MadhyaPradesh
# 2209950  Indore  MadhyaPradesh
# 2210006  Indore  MadhyaPradesh
# 2210038  Indore  MadhyaPradesh
# 2210859  Indore  MadhyaPradesh
# 2210917  Indore  MadhyaPradesh
# 2210921  Indore  MadhyaPradesh
# 2210988  Indore  MadhyaPradesh
# 2211026  Indore  MadhyaPradesh
# 2211072  Indore  MadhyaPradesh
# 2211089  Indore  MadhyaPradesh
# 2211091  Indore  MadhyaPradesh
# 2211234  Indore  MadhyaPradesh
# ...         ...            ...
# 2211368  Indore  MadhyaPradesh
# 2211383  Indore  MadhyaPradesh
# 2211406  Indore  MadhyaPradesh
# 2211407  Indore  MadhyaPradesh
# 2211423  Indore  MadhyaPradesh
# 2211465  Indore  MadhyaPradesh
# 2211585  Indore  MadhyaPradesh
# 2211617  Indore  MadhyaPradesh
# 2211635  Indore  MadhyaPradesh
# 2231166  Indore  MadhyaPradesh
# 2231224  Indore  MadhyaPradesh
# 2231228  Indore  MadhyaPradesh
# 2231295  Indore  MadhyaPradesh
# 2231333  Indore  MadhyaPradesh
# 2231379  Indore  MadhyaPradesh
# 2231396  Indore  MadhyaPradesh
# 2231398  Indore  MadhyaPradesh
# 2231541  Indore  MadhyaPradesh
# 2231553  Indore  MadhyaPradesh
# 2231618  Indore  MadhyaPradesh
# 2231662  Indore  MadhyaPradesh
# 2231675  Indore  MadhyaPradesh
# 2231690  Indore  MadhyaPradesh
# 2231713  Indore  MadhyaPradesh
# 2231714  Indore  MadhyaPradesh
# 2231730  Indore  MadhyaPradesh
# 2231772  Indore  MadhyaPradesh
# 2231836  Indore  MadhyaPradesh
# 2231892  Indore  MadhyaPradesh
# 2231924  Indore  MadhyaPradesh
#
# [63 rows x 7 columns]

# %%
#Filling missing longtitude and latitude of Indore , Madhya Pradesh
#https://www.latlong.net/search.php?keyword=indore
#Indore 22.719568	75.857727
#Indore 23.200001	77.080002

selectedStates.fillna({'longitude':'75.857727','latitude':'22.719568'},inplace=True)

selectedStates[selectedStates.isnull().any(axis=1)].sum()

# no more null values in Longitude and latitude
# Out:
# event_id     0.0
# device_id    0.0
# timestamp    0.0
# longitude    0.0
# latitude     0.0
# city         0.0
# state        0.0
# dtype: float64

# %%
#!pip install folium

# %%
# Putting latitude and longitude into list

locations = selectedStates[['latitude', 'longitude']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist
# Out:
# [[22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.76917000000001, 75.939543],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.746807, 75.935055],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.750856, 75.889129],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.80996, 75.919742],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.803521, 75.876397],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.81151, 75.95003299999998],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  [22.78677, 75.908495],
#  ...]

# %%
#Plotting latitude and longitude using folium package
import folium as folium

# Initialize the map:
latitude = 22.746807
longitude = 75.935055
map = folium.Map(location=[latitude, longitude], zoom_start=12)

#plotting the selected longitude and latitude
for point in range(0, 4):
    folium.Marker(locationlist[point], popup=selectedStates['city']).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map2 = folium.Map(location=[22.80996, 75.919742], tiles='CartoDB dark_matter', zoom_start=10)

#marker_cluster = folium.MarkerCluster().add_to(map2)

for point in range(0, 5):
    folium.Marker(locationlist[point], popup=selectedStates['city']).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exploratory Data Analysis - EDA

# %% [markdown]
# ### Distribution of Users(device_id) across States.

# %%
# Displaying different users across States [ Chattisgarh , Goa,Nag,JammuandKashmir,MadhyaPradesh,Uttaranchal]

selectedStates.groupby('state').device_id.nunique()
# Out:
# state
# Chhattisgarh        400
# Goa                  76
# JammuandKashmir     236
# MadhyaPradesh      3220
# Uttaranchal         258
# Name: device_id, dtype: int64

# %%
# plot the above distribution 

selectedStates.groupby('state')['device_id'].nunique().plot(kind='bar',grid = True)

# %% [markdown]
# ### Distribution of Users across Phone Brands(Consider only 10 Most used Phone Brands).

# %%
# Displaying users across top 10 phone brands

Top10Brands = pd.DataFrame(gender_Phone_brand.groupby('EnglishBrandName')['device_id'].nunique().sort_values(ascending=False).head(10))

Top10Brands
# Out:
#                   device_id
# EnglishBrandName
# Xiaomi                 9195
# Samsung                8123
# Huawei                 6444
# vivo                   3241
# OPPO                   2874
# Meizu                  2353
# Coolpad                1658
# HTC                     557
# 联想                      405
# LeEco                   358

# %%
# Plotting Users across top 10 brands

Top10Brands.plot(kind = 'barh')

# %% [markdown]
# ## Distribution of Users across Gender.

# %% [markdown]
# The number of MALE users are double that of FEMALE

# %%
# Gender wise distribution

GenderDistribution = pd.DataFrame(gender_Phone_brand.groupby('gender')['device_id'].nunique())
 
GenderDistribution
# Out:
#         device_id
# gender
# F           13373
# M           23850

# %%
# Plotting Gender distribution

GenderDistribution.plot(kind='pie',y='device_id')

# %% [markdown]
# ## Distribution of Users across Age Segments.

# %%
# Filtering the Age segment distribution

gender_Phone_brand.groupby('group')['device_id'].nunique()
# Out:
# group
# F23-      2529
# F24-26    2145
# F27-28    1525
# F29-32    2338
# F33-42    2743
# F43+      2093
# M22-      3706
# M23-26    4786
# M27-28    2698
# M29-31    3664
# M32-38    4723
# M39+      4273
# Name: device_id, dtype: int64

# %%
# PLotting the Age-segments

gender_Phone_brand.groupby('group')['device_id'].nunique().plot(kind='barh')

# %%
# gender_Phone_brand

# %%
# function to map to common age-segment based on age column, irrespective of gender
# common six Age segment are - 22- ,23-26,27-28,29-32,33-42,43+

def getAgeSegment():
    '''
    Function to map to common age-segment based on age column
    '''
    for index, row in gender_Phone_brand.iterrows():
        if (row['age'] == 22 or row['age'] < 22 ):
            row['AgeSegment'] = '22-'
        elif row['age'] in range(23,26):
            row['AgeSegment'] = '23-26'
        elif row['age'] in range(27,28):
            row['AgeSegment'] = '27-28'
        elif row['age'] in range(29,32):
            row['AgeSegment'] = '29-32'
        elif row['age']  in range(33,42):
            row['AgeSegment'] = '33-42'
        elif (row['age'] == 43 or row['age'] > 43 ):
            row['AgeSegment'] = '43+'      
        
    return

# %%
def getAgeSegmentMapping(age):
    '''
    The function used to retrive the age segment based on the input age. 
    '''
    segment = 'NA'
    
    if (age == 22 or age < 22):
        segment = '22-'
    elif age in range(23,27):
        segment = '23-26'
    elif age in range(27,29):
        segment = '27-28'
    elif age in range(29,33):
        segment = '29-32'
    elif age  in range(33,43):
        segment = '33-42'
    elif (age == 43 or age > 43 ):
        segment = '43+' 
            
        
    return segment

# %%
gender_Phone_brand['AgeSegment'] = gender_Phone_brand.age.apply(lambda x:getAgeSegmentMapping(x))
gender_Phone_brand.head()
# Out:
#              device_id gender  age   group  Unnamed: 0 phone_brand  \
# 0   245133531816851882      M   30  M29-31       13110       SUGAR
# 1   236877999787307864      M   36  M32-38       68989          酷派
# 2   176515041953473526      M   33  M32-38       13112          华为
# 3  1596610250680140042      F   36  F33-42       67545          三星
# 4  9032155484127182494      M   31  M29-31       77024          华为
#
#   device_model EnglishBrandName AgeSegment
# 0         时尚手机            SUGAR      29-32
# 1           F2          Coolpad      33-42
# 2        G610S           Huawei      33-42
# 3    Galaxy S4          Samsung      33-42
# 4       Mate 7           Huawei      29-32

# %%
# grouping users based on common age segments

gender_Phone_brand.groupby('AgeSegment')['device_id'].nunique()
# Out:
# AgeSegment
# 22-      5667
# 23-26    7499
# 27-28    4223
# 29-32    6889
# 33-42    8002
# 43+      4943
# Name: device_id, dtype: int64

# %% [markdown]
# ### 5. Distribution of Phone Brands(Consider only 10 Most used Phone Brands) for each Age Segment, State, Gender.

# %%
top_brands_list = gender_Phone_brand.EnglishBrandName.value_counts()[:10].reset_index()["index"].tolist()
top_brands_list
# Out:
# ['Xiaomi',
#  'Samsung',
#  'Huawei',
#  'vivo',
#  'OPPO',
#  'Meizu',
#  'Coolpad',
#  'HTC',
#  '联想 ',
#  'LeEco']

# %%
# Get the top 10 phone brand filtered records.
gender_Phone_brand_filtered = gender_Phone_brand[gender_Phone_brand.EnglishBrandName.isin(top_brands_list)]

# %% [markdown]
# #### Phone brands vs gender

# %%
phone_brand_gender_report = gender_Phone_brand_filtered[['EnglishBrandName', 'gender']]
phone_brand_gender_report_group = pd.pivot_table(phone_brand_gender_report,index=["EnglishBrandName"],columns=["gender"],aggfunc=[len])
phone_brand_gender_report_group.plot.bar(stacked=True)
plt.xlabel("Types of brands")
plt.ylabel("Number of users")
plt.title("Distribution of Male & Female users across Phone Brands")
# Out:
# Text(0.5, 1.0, 'Distribution of Male & Female users across Phone Brands')

# %% [markdown]
# #### Phone brands vs age segments

# %%
phone_brand_agesegment_report = gender_Phone_brand_filtered[['EnglishBrandName', 'AgeSegment']]
phone_brand_agesegment_report_group = pd.pivot_table(phone_brand_agesegment_report,index=["EnglishBrandName"],columns=["AgeSegment"],aggfunc=[len])
phone_brand_agesegment_report_group.plot.bar(stacked=True)
plt.xlabel("Types of brands")
plt.ylabel("Age segment")
plt.title("Distribution of age segment across Phone Brands")
# Out:
# Text(0.5, 1.0, 'Distribution of age segment across Phone Brands')

# %% [markdown]
# #### Phone brands vs states

# %%
# selectedStates.isnull().sum()
phone_brand['EnglishBrandName'] = phone_brand.apply(lambda x:getBrandValue(x['phone_brand']),axis=1)
Phone_brand_states = pd.merge(selectedStates,phone_brand,on = 'device_id',how='inner')

Phone_brand_states_report = Phone_brand_states[['EnglishBrandName', 'state']]
Phone_brand_states_report_group = pd.pivot_table(Phone_brand_states_report,index=["EnglishBrandName"],columns=["state"],aggfunc=[len])
Phone_brand_states_report_group
# Out:
#                           len
# state            Chhattisgarh MadhyaPradesh
# EnglishBrandName
# HTC                       1.0           NaN
# Huawei                    1.0           NaN
# Samsung                   NaN         543.0
# Xiaomi                    NaN         733.0
# vivo                      NaN         132.0

# %%
Phone_brand_states_report_group.plot.bar(stacked=True)
plt.xlabel("Types of brands")
plt.ylabel("States")
plt.title("Distribution of states across Phone Brands")
# Out:
# Text(0.5, 1.0, 'Distribution of states across Phone Brands')

# %% [markdown]
# ### 6. Distribuiion of Gender for each State, Age Segment and Phone Brand(Consider only 10 Most used Phone Brands).

# %% [markdown]
# ### 7. Distribution of Age Segments for each State, Gender and Phone Brand(Consider only 10 Most used Phone Brands).
#
# Note: While doing analysis for the above points, consider only one instance of a particular User(device_id) as a User can do multiple phone calls and considering every instance of the same User can give misleading numbers.

# %% [markdown]
# ### 8. Hourly distribution of Phone Calls.

# %% [markdown]
# ### 9. Plot the Users on the Map using any suitable package.

# %% [markdown]
# - Stack chart for Age segment (bar) vs phone brand (multi rows)
# - Phone brand vs state
# - Stack chart for phone brand (bar) vs gender (multi rows)

# %% [markdown]
# Here is the Task for Week 3:
#
# 1. Do Analysis on the preprocessed Data.
#
# Here are the points about how Analysis should be done:
#
# 1. Distribution of Users(device_id) across States.
#
# 2. Distribution of Users across Phone Brands(Consider only 10 Most used Phone Brands).
#
# 3. Distribution of Users across Gender.
#
# 4. Distribution of Users across Age Segments.
#
# 5. Distribution of Phone Brands(Consider only 10 Most used Phone Brands) for each Age Segment, State, Gender.
#
# 6. Distribuiion of Gender for each State, Age Segment and Phone Brand(Consider only 10 Most used Phone Brands).
#
# 7. Distribution of Age Segments for each State, Gender and Phone Brand(Consider only 10 Most used Phone Brands).
#
#
# Note: While doing analysis for the above points, consider only one instance of a particular User(device_id) as a User can do multiple phone calls and considering every instance of the same User can give misleading numbers.
#
# 8. Hourly distribution of Phone Calls.
#
# 9. Plot the Users on the Map using any suitable package.
#
# Note: Do not open the Data in Excel. Doing so will corrupt the Data and will be problematic while uploading the Data into Database. You can examine the Data by opening in a Text Editor(Notepad, EditPlus, Notepad++ etc).
